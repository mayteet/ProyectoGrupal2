# %%
import pandas as pd
import numpy as np

# %%
glassdor=pd.read_csv("Dataset\glassdoor.csv")
glassdor.head()
# Out:
#    benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 0                            0.0             2801.0               2801.0
# 1                            4.0             2802.0               2802.0
# 2                            0.0             2803.0               2803.0
# 3                            0.0             2804.0               2804.0
# 4                            0.0             2805.0               2805.0
#
#    benefits.numRatings benefits.employerSummary  breadCrumbs  \
# 0                    0                      NaN         2801
# 1                    3                      NaN         2802
# 2                    0                      NaN         2803
# 3                    0                      NaN         2804
# 4                    0                      NaN         2805
#
#    gaTrackerData.category  gaTrackerData.empId  gaTrackerData.empName  \
# 0                      -1              2183810            Modus Group
# ...

# %%
country_names= pd.read_csv("Dataset\country_names_2_digit_codes.csv")
country_names.head()
# Out:
#              Name Code
# 0     Afghanistan   AF
# 1  Ã…land Islands   AX
# 2         Albania   AL
# 3         Algeria   DZ
# 4  American Samoa   AS

# %%
currency_exchange= pd.read_csv("Dataset\currency_exchange.csv")
currency_exchange.head()
# Out:
#   Code                     Country                       Currency  Number  \
# 0  AED  United Arab Emirates (The)                     UAE Dirham   784.0
# 1  AFN                 Afghanistan                        Afghani   971.0
# 2  ALL                     Albania                            Lek     8.0
# 3  AMD                     Armenia                  Armenian Dram    51.0
# 4  ANG                     Curaçao  Netherlands Antillean Guilder   532.0
#
#    ExchangeRate
# 0      3.672779
# 1     78.250197
# 2    111.702860
# 3    477.169811
# 4      1.734311

# %%
glassdoor_photos= pd.read_csv("Dataset\glassdoor_photos.csv")
glassdoor_photos.head()
# Out:
#       id  index       photos.val.caption  photos.val.photoId  \
# 0  26411      0                Mango day            10772510
# 1  26411      1  We REALLY like cupcakes            17246228
# 2  26411      2              Heli-skiing            17223544
# 3  26411      3   Rocking out in Karachi            17223536
# 4  26411      4             New offices!            17223528
#
#    photos.val.photoId2x                          photos.val.photoLink  \
# 0              10772511  /Photos/Afiniti-Office-Photos-IMG1912051.htm
# 1              17246229  /Photos/Afiniti-Office-Photos-IMG3404357.htm
# 2              17223545  /Photos/Afiniti-Office-Photos-IMG3399151.htm
# 3              17223537  /Photos/Afiniti-Office-Photos-IMG3399150.htm
# 4              17223529  /Photos/Afiniti-Office-Photos-IMG3399149.htm
#
#                                  photos.val.photoUrl  \
# 0  https://media.glassdoor.com/lst/1436090/afinit...
# 1  https://media.glassdoor.com/lst/c3/26/ff/81/we...
# ...

# %%
glassdoor_benefits_comments= pd.read_csv("Dataset\glassdoor_benefits_comments.csv")
glassdoor_benefits_comments.tail()
# Out:
#            id  index benefits.comments.val.city  \
# 271431  33598    0.0                     London
# 271432  33599    0.0                    Cwmbran
# 271433  33599    1.0                     Slough
# 271434  33599    2.0                    Cwmbran
# 271435  33600    NaN                        NaN
#
#                             benefits.comments.val.comment  \
# 271431                they don;t offer a benefit package
# 271432  company paid activities such as sky diving, hi...
# 271433  Pension, health cover, benefits package, buy a...
# 271434              you can "buy" additional annual leave
# 271435                                                NaN
#
#        benefits.comments.val.createDate benefits.comments.val.currentJob  \
# 271431           2019-10-30 11:59:47.16                            False
# 271432          2019-05-23 17:03:30.183                            False
# 271433           2019-01-24 15:41:23.12                            False
# ...

# %%
glassdoor_benefits_comments["benefits.comments.val.createDate"].sort_values(ascending=False)
# Out:
# 263416    2019-11-10 14:25:20.0
# 133943    2019-11-10 14:25:20.0
# 147441    2019-11-10 14:25:20.0
# 137155    2019-11-10 14:25:20.0
# 208080    2019-11-10 14:25:20.0
#                   ...
# 271417                      NaN
# 271418                      NaN
# 271419                      NaN
# 271429                      NaN
# 271435                      NaN
# Name: benefits.comments.val.createDate, Length: 271436, dtype: object

# %%
glassdor_benefits_highlights= pd.read_csv("Dataset\glassdoor_benefits_highlights.csv")
glassdor_benefits_highlights.head()
# Out:
#       id            benefits.highlights.val.highlightPhrase  \
# 0  44001             good flexibility for working from home
# 1  44001  I’ve not really had any time off for the last ...
# 2  44001  Very flexible if you don't work overtime and y...
# 3  44002                                                NaN
# 4  44003                                                NaN
#
#   benefits.highlights.val.icon benefits.highlights.val.name  index  \
# 0                          wfh               Work From Home    0.0
# 1                     sickDays                     Sick Pay    1.0
# 2                flexWorkSched             Flexible Working    2.0
# 3                          NaN                          NaN    NaN
# 4                          NaN                          NaN    NaN
#
#    benefits.highlights.val.commentCount
# 0                                  17.0
# 1                                  14.0
# 2                                   7.0
# ...

# %%
glassdoor_breadCrumbs= pd.read_csv("Dataset\glassdoor_breadCrumbs.csv")
glassdoor_breadCrumbs.tail()
# Out:
#            id  index breadCrumbs.val.name breadCrumbs.val.url
# 165285  32396      0                 JOBS      /Job/index.htm
# 165286  32397      0                 JOBS      /Job/index.htm
# 165287  32398      0                 JOBS      /Job/index.htm
# 165288  32399      0                 JOBS      /Job/index.htm
# 165289  32400      0                 JOBS      /Job/index.htm

# %%
glassdoor_rev= pd.read_csv("Dataset\glassdoor_reviews.csv")
glassdoor_rev.head()
# Out:
#       id  index                                   reviews.val.cons  \
# 0  44001    0.0               Still not big enough in market place
# 1  44002    NaN                                                NaN
# 2  44003    NaN                                                NaN
# 3  44004    0.0             Nothing important on my point of view.
# 4  44004    1.0  Alot of friends working together which isn't v...
#
#   reviews.val.date reviews.val.featured  reviews.val.helpfulCount  \
# 0     Oct 20, 2010                False                       0.0
# 1              NaN                  NaN                       NaN
# 2              NaN                  NaN                       NaN
# 3      4 weeks ago                False                       0.0
# 4     May 29, 2019                False                       0.0
#
#    reviews.val.id                                   reviews.val.pros  \
# 0        689142.0  Great brand , Good leadership , Clear business...
# ...

# %%
glassdoor_overview_competitors= pd.read_csv("Dataset\glassdoor_overview_competitors.csv")
glassdoor_overview_competitors.tail()
# Out:
#            id  index overview.competitors.val
# 133331  11240      1            Merrill Lynch
# 133332  11240      2           Morgan Stanley
# 133333  11241      0                     Audi
# 133334  11241      1                  Porsche
# 133335  11241      2                      BMW

# %%
glassdoor_reviews=pd.read_csv("Dataset\glassdoor_reviews_val_reviewResponses.csv")
glassdoor_reviews.head()
# Out:
#      id  index reviews.val.reviewResponses.val.createDate  \
# 0  6762      0                        2018-05-01T03:54:11
# 1  6763      0                        2018-07-17T06:15:22
# 2  6764      0                        2019-01-04T11:48:06
# 3  6765      0                        2018-07-25T12:07:51
# 4  6766      0                        2019-01-16T02:02:05
#
#    reviews.val.reviewResponses.val.helpfulCount  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    reviews.val.reviewResponses.val.jobTitle  \
# 0                                       NaN
# 1  Culture &amp; Engagement Program Manager
# 2  Culture &amp; Engagement Program Manager
# 3  Culture &amp; Engagement Program Manager
# 4          Marketing Communications Manager
#
# ...

# %%
glassdoor_salary_salaries=pd.read_csv("Dataset\glassdoor_salary_salaries.csv")
glassdoor_salary_salaries.head()
# Out:
#    id  index  salary.salaries.val.basePayCount salary.salaries.val.jobTitle  \
# 0   1    NaN                               NaN                          NaN
# 1   2    0.0                               9.0          Advanced Consultant
# 2   2    1.0                               7.0                   Consultant
# 3   2    2.0                               7.0            Software Engineer
# 4   2    3.0                               4.0              Project Manager
#
#   salary.salaries.val.payPeriod  \
# 0                           NaN
# 1                        ANNUAL
# 2                        ANNUAL
# 3                        ANNUAL
# 4                        ANNUAL
#
#    salary.salaries.val.salaryPercentileMap.payPercentile10  \
# 0                                                NaN
# 1                                           32257.68
# 2                                           28855.30
# 3                                           30377.86
# ...

# %%
glassdoor_wwfu= pd.read_csv("Dataset\glassdoor_wwfu.csv")
glassdoor_wwfu.head()
# Out:
#     id  index                                      wwfu.val.body  wwfu.val.id  \
# 0  449      0  <p><img class="lazy" style="display: block; ma...       133403
# 1  449      1  <p><iframe style="display: block; margin-left:...       133404
# 2  449      2  <p><img class="lazy" style="display: block; ma...       133405
# 3  449      3  <p><iframe style="display: block; margin-left:...       133406
# 4  449      4  <p style="text-align: center;"><iframe src="ht...       133407
#
#   wwfu.val.title wwfu.val.type  wwfu.val.videos  wwfu.val.photos  \
# 0       About Us        CUSTOM              NaN              NaN
# 1        Careers        CUSTOM              NaN              NaN
# 2       Benefits        CUSTOM              NaN              NaN
# 3    Why Micron?        CUSTOM              NaN              NaN
# 4      Diversity        CUSTOM              NaN              NaN
#
#    wwfu.val.captions
# 0                NaN
# 1                NaN
# 2                NaN
# ...

# %%
glassdoor_wwfu_val_captions= pd.read_csv("Dataset\glassdoor_wwfu_val_captions.csv")
glassdoor_wwfu_val_captions.head()
# Out:
#      id  index                              wwfu.val.captions.val
# 0  1407      0                              Our interview process
# 1  1408      0           Andrew Watson | Head of Machine Learning
# 2  1408      1           Connected studio | Singapore Tech Centre
# 3  1409      0           Melloney Luckhurst- UI Designer at Dyson
# 4  1409      1  Dyson UK campus, D9 (left) Lightning Cafe (right)

# %%
glassdoor_wwfu_val_photos= pd.read_csv("Dataset\glassdoor_wwfu_val_photos.csv")
glassdoor_wwfu_val_photos.head()
# Out:
#      id  index                                wwfu.val.photos.val
# 0  2370      0  https://media.glassdoor.com/template/l/40772/f...
# 1  2371      0  https://media.glassdoor.com/template/l/40772/f...
# 2  2372      0  https://media.glassdoor.com/template/l/1162798...
# 3  2373      0  https://media.glassdoor.com/template/l/1162798...
# 4  2374      0  https://media.glassdoor.com/template/l/7774/ta...

# %%
glassdoor_wwfu_val_videos= pd.read_csv("Dataset\glassdoor_wwfu_val_videos.csv")
glassdoor_wwfu_val_videos.head()
# Out:
#      id  index                                wwfu.val.videos.val
# 0  4327      0  <iframe width="560" height="315" src="https://...
# 1  4328      0  <iframe width="560" height="315" src="https://...
# 2  4329      0  <iframe width="560" height="315" src="https://...
# 3  4330      0  <iframe width="560" height="315" src="https://...
# 4  4331      0  <iframe width="560" height="315" src="https://...

# %% [markdown]
# ETL

# %% [markdown]
# Obtención de tabla de empresas

# %%
empresas=glassdor[["gaTrackerData.empId","gaTrackerData.empName", "gaTrackerData.empSize"]].drop_duplicates().reset_index(drop=True)
empresas= empresas.rename(columns={'gaTrackerData.empId':'emp_ID',
                                   'gaTrackerData.empName':'emp_Name',
                                   'gaTrackerData.empSize':'emp_Size'
    
})
empresas.set_index("emp_ID", inplace=True)
empresas.sort_index()

empresas.to_csv("empresas.csv")
empresas.head()
# Out:
#                       emp_Name  emp_Size
# emp_ID
# 2183810            Modus Group  501-1000
# 10416     Boehringer Ingelheim  10000--1
# 1043373        Immobiliare.it    201-500
# 2226886                  Codup      1-50
# 851555   Markelytics Solutions   201-500
